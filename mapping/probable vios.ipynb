# %%
from probable_vio_mapper import *

# %%
from branca import colormap

# %%
cmap = colormap.LinearColormap([(102, 188, 116), (196, 213, 118),
           (249, 214, 52), (254, 122, 85), (255, 70, 55)],
                   vmin=0, vmax=100, index=[0, 25, 70, 85, 95],
                  caption="Violation Probability Index")

# %%
cmap
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#66bc74ff;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#67bc74ff;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#67bd74ff;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#68bd74ff;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#69bd74ff;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#6abd74ff;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#6abd74ff;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#6bbe74ff;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#6cbe74ff;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#6dbe74ff;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#6dbe74ff;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#6ebe74ff;stroke-width:3;" /><line x1="12" y1="0" x2="12" y2="20" style="stroke:#6fbf74ff;stroke-width:3;" /><line x1="13" y1="0" x2="13" y2="20" style="stroke:#70bf74ff;stroke-width:3;" /><line x1="14" y1="0" x2="14" y2="20" style="stroke:#70bf74ff;stroke-width:3;" /><line x1="15" y1="0" x2="15" y2="20" style="stroke:#71bf74ff;stroke-width:3;" /><line x1="16" y1="0" x2="16" y2="20" style="stroke:#72bf74ff;stroke-width:3;" /><line x1="17" y1="0" x2="17" y2="20" style="stroke:#73c074ff;stroke-width:3;" /><line x1="18" y1="0" x2="18" y2="20" style="stroke:#74c074ff;stroke-width:3;" /><line x1="19" y1="0" x2="19" y2="20" style="stroke:#74c074ff;stroke-width:3;" /><line x1="20" y1="0" x2="20" y2="20" style="stroke:#75c074ff;stroke-width:3;" /><line x1="21" y1="0" x2="21" y2="20" style="stroke:#76c074ff;stroke-width:3;" /><line x1="22" y1="0" x2="22" y2="20" style="stroke:#77c174ff;stroke-width:3;" /><line x1="23" y1="0" x2="23" y2="20" style="stroke:#77c174ff;stroke-width:3;" /><line x1="24" y1="0" x2="24" y2="20" style="stroke:#78c174ff;stroke-width:3;" /><line x1="25" y1="0" x2="25" y2="20" style="stroke:#79c174ff;stroke-width:3;" /><line x1="26" y1="0" x2="26" y2="20" style="stroke:#7ac174ff;stroke-width:3;" /><line x1="27" y1="0" x2="27" y2="20" style="stroke:#7ac274ff;stroke-width:3;" /><line x1="28" y1="0" x2="28" y2="20" style="stroke:#7bc274ff;stroke-width:3;" /><line x1="29" y1="0" x2="29" y2="20" style="stroke:#7cc274ff;stroke-width:3;" /><line x1="30" y1="0" x2="30" y2="20" style="stroke:#7dc274ff;stroke-width:3;" /><line x1="31" y1="0" x2="31" y2="20" style="stroke:#7dc274ff;stroke-width:3;" /><line x1="32" y1="0" x2="32" y2="20" style="stroke:#7ec374ff;stroke-width:3;" /><line x1="33" y1="0" x2="33" y2="20" style="stroke:#7fc374ff;stroke-width:3;" /><line x1="34" y1="0" x2="34" y2="20" style="stroke:#80c375ff;stroke-width:3;" /><line x1="35" y1="0" x2="35" y2="20" style="stroke:#80c375ff;stroke-width:3;" /><line x1="36" y1="0" x2="36" y2="20" style="stroke:#81c375ff;stroke-width:3;" /><line x1="37" y1="0" x2="37" y2="20" style="stroke:#82c475ff;stroke-width:3;" /><line x1="38" y1="0" x2="38" y2="20" style="stroke:#83c475ff;stroke-width:3;" /><line x1="39" y1="0" x2="39" y2="20" style="stroke:#83c475ff;stroke-width:3;" /><line x1="40" y1="0" x2="40" y2="20" style="stroke:#84c475ff;stroke-width:3;" /><line x1="41" y1="0" x2="41" y2="20" style="stroke:#85c475ff;stroke-width:3;" /><line x1="42" y1="0" x2="42" y2="20" style="stroke:#86c575ff;stroke-width:3;" /><line x1="43" y1="0" x2="43" y2="20" style="stroke:#86c575ff;stroke-width:3;" /><line x1="44" y1="0" x2="44" y2="20" style="stroke:#87c575ff;stroke-width:3;" /><line x1="45" y1="0" x2="45" y2="20" style="stroke:#88c575ff;stroke-width:3;" /><line x1="46" y1="0" x2="46" y2="20" style="stroke:#89c575ff;stroke-width:3;" /><line x1="47" y1="0" x2="47" y2="20" style="stroke:#89c675ff;stroke-width:3;" /><line x1="48" y1="0" x2="48" y2="20" style="stroke:#8ac675ff;stroke-width:3;" /><line x1="49" y1="0" x2="49" y2="20" style="stroke:#8bc675ff;stroke-wid ...

# %%
centroids = pd.read_csv('../groupby_prep/license_centroids.csv')
centroids = gp.GeoDataFrame(centroids, geometry=centroids.geometry.apply(shapely.wkt.loads))

# %%
centroids[centroids.license=='STR-419049'].violator_prob_rating
# Out:
# 0    98.0
# Name: violator_prob_rating, dtype: float64

# %%
419049

# %%
def calc_font_color(x):
    r, g, b = (int(cmap(x)[1:3], 16), int(cmap(x)[3:5], 16), int(cmap(x)[5:7], 16))
    print((float(r)*0.299 + float(g)*0.587 + float(b)*0.114))
    if (float(r)*0.299 + float(g)*0.587 + float(b)*0.114) > 195:
        return "#000"
    else: return "#fff"

# %%
city_overview()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
license_focus = 'STR-419049'
m, data = license_listings(license_focus)
m
