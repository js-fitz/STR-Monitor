# %%
import folium
import geopandas
import numpy as np
import pandas as pd
import project_functions
from tqdm.notebook import tqdm

# %%
# %%capture
tqdm.pandas()

# %%
tracts = geopandas.read_file('Census_2010_Tracts.geojson')
props = pd.read_csv('props_combined.csv', low_memory=0).rename(columns={'Unnamed: 0': 'PID'})
props = geopandas.GeoDataFrame(props, geometry=geopandas.points_from_xy(props.X, props.Y))
props.crs = tracts.crs

# %%
m = folium.Map([42.328034, -71.078358],
                zoom_start=11,
                tiles='cartodbpositron')
tracts_gjson = tracts.to_crs(epsg=str(tracts.crs).split(':')[1]).to_json()
points = folium.features.GeoJson(tracts_gjson)
m.add_children(points)
# Out:
# /Users/jfitz/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:6: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
